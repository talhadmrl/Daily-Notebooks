# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("5-diamonds.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df[df["x"]==0]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
df = df.drop(df[df["x"]==0].index)
df = df.drop(df[df["y"]==0].index)
df = df.drop(df[df["z"]==0].index)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.scatterplot(x=df["x"],y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["y"],y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["z"],y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["table"],y=df["price"])
plt.show()

# %%
sns.scatterplot(x=df["depth"],y=df["price"])
plt.show()

# %%
#outlier değerler çıkarıldı
df = df[(df["x"]<10)]
df = df[(df["y"]<20)]
df = df[(df["z"]<8)&(df["z"]>2)]
df = df[(df["table"]<73)&(df["table"]>42)]
df = df[(df["depth"]<73)&(df["depth"]>53)]

# %%
sns.scatterplot(x=df["depth"],y=df["price"])
plt.show()

# %%
# Encoding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53890 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53890 non-null  float64
#  1   cut      53890 non-null  object
#  2   color    53890 non-null  object
#  3   clarity  53890 non-null  object
#  4   depth    53890 non-null  float64
#  5   table    53890 non-null  float64
#  6   price    53890 non-null  int64
#  7   x        53890 non-null  float64
#  8   y        53890 non-null  float64
#  9   z        53890 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21543
# Premium      13777
# Very Good    12079
# Good          4902
# Fair          1589
# Name: count, dtype: int64

# %%
X=df.drop("price",axis=1)
y=df["price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
for col in ["cut","color","clarity"]:
    X_train[col] =label.fit_transform(X_train[col])
    X_test[col] =label.transform(X_test[col])

# %%
X_train.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  40417.000000  40417.000000  40417.000000  40417.000000  40417.000000
# mean       0.796549      2.556622      2.595220      3.839201     61.752560
# std        0.471501      1.024645      1.699837      1.726370      1.406682
# min        0.200000      0.000000      0.000000      0.000000     53.200000
# 25%        0.400000      2.000000      1.000000      2.000000     61.000000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.040000      3.000000      4.000000      5.000000     62.500000
# max        3.670000      4.000000      6.000000      7.000000     72.900000
#
#               table             x             y             z
# count  40417.000000  40417.000000  40417.000000  40417.000000
# mean      57.447841      5.729572      5.731473      3.538428
# std        2.217992      1.117580      1.109632      0.690020
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40417 entries, 40938 to 7631
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40417 non-null  float64
#  1   cut      40417 non-null  int64
#  2   color    40417 non-null  int64
#  3   clarity  40417 non-null  int64
#  4   depth    40417 non-null  float64
#  5   table    40417 non-null  float64
#  6   x        40417 non-null  float64
#  7   y        40417 non-null  float64
#  8   z        40417 non-null  float64
# dtypes: float64(6), int64(3)
# memory usage: 3.1 MB

# %%
# model training
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train_scaled =scaler.fit_transform(X_train)
X_test_scaled =scaler.transform(X_test)

# %%
#lineer regresyon
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
linear =LinearRegression()
linear.fit(X_train_scaled,y_train)
y_pred=linear.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mae: ",mae)
print("mse: ",mse)
print("r2: ",r2)
# Out:
# mae:  855.1179011275339
# mse:  1781525.6002899667
# r2:  0.8876566507396759

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %%
# SVR
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train_scaled,y_train)
y_pred=svr.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mae: ",mae)
print("mse: ",mse)
print("r2: ",r2)
# Out:
# mae:  1379.3255122444623
# mse:  7955233.308350591
# r2:  0.49834144743026465

# %%
# grid.best_params  'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'

# %%
from sklearn.svm import SVR
svr=SVR(C=1000,gamma=0.1,kernel="rbf")
svr.fit(X_train_scaled,y_train)
y_pred=svr.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("mae: ",mae)
print("mse: ",mse)
print("r2: ",r2)
# Out:
# mae:  476.0753963844733
# mse:  859080.7643874149
# r2:  0.9458262006784001

# %%
# Kullanıcıdan veri alma
carat = float(input("Carat değerini gir (örnek: 0.7): "))
cut = input("Kesim kalitesi (Fair, Good, Very Good, Premium, Ideal): ")
color = input("Renk (J, I, H, G, F, E, D): ")
clarity = input("Berraklık (I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF): ")
depth = float(input("Depth oranı (örnek: 61.5): "))
table = float(input("Table oranı (örnek: 57): "))
x = float(input("x değeri (örnek: 5.7): "))
y = float(input("y değeri (örnek: 5.8): "))
z = float(input("z değeri (örnek: 3.5): "))
# Out:
# Carat değerini gir (örnek: 0.7):  2.5
# Kesim kalitesi (Fair, Good, Very Good, Premium, Ideal):  3
# Renk (J, I, H, G, F, E, D):  3
# Berraklık (I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF):  2
# Depth oranı (örnek: 61.5):  66.6
# Table oranı (örnek: 57):  55.5
# x değeri (örnek: 5.7):  6
# y değeri (örnek: 5.8):  5
# z değeri (örnek: 3.5):  4

# %%
new_data = pd.DataFrame({
    'carat': [carat],
    'cut': [cut],
    'color': [color],
    'clarity': [clarity],
    'depth': [depth],
    'table': [table],
    'x': [x],
    'y': [y],
    'z': [z]
})

# %%
new_data_scaled = scaler.transform(new_data)

predicted_price = svr.predict(new_data_scaled)
print(f"\n Tahmini Elmas Fiyatı: ${predicted_price[0]:,.2f}")
# Out:
#  Tahmini Elmas Fiyatı: $6,173.91
